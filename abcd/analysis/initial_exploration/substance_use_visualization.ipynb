# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import pandas as pd
from abcd.local.paths import core_path, output_path
from abcd.data.read_data import get_subjects_events, add_event_vars
from abcd.data.define_splits import SITES, save_restore_sex_fmri_splits

# %%
# Fetch subjects and events
subjects_df, events_df = get_subjects_events()

# %%
# Add substance use beh
SU_SCORES = {"tlfb_alc_sip": "Ever tried?",
             "su_isip_1_calc": "Total times 1 sip",
             "isip_1b_yn": "Ever alcohol not in religious ceremony",
             "tlfb_alc_reg": "Regular drinking",
             "tlfb_alc_lt": "Total drinks",
             "xskipout_alc": "Drinking days past 6 months"}    

su_file = os.path.join(core_path, "substance-use", "su_y_sui.csv")
su_events_df = add_event_vars(events_df, su_file, vars=list(SU_SCORES.keys()))
# Out:
# c:\users\camgonza\desktop\abcd5\abcd\utils\io.py:24: DtypeWarning: Columns (92,95,107,112,117,122,127,132,137,150,153,155,160,170,175,190,223,245,248,250,255,258,260,265,417,419,421,423,425,427,429,431,433,435,437,441,443,449,460,471,473,475,477,479,536,673,709,712,718,721,727,730,733,736,739,742,745,748,751,754,759,763,772,775,784,787,790,799,802,805,808,811,814) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, sep=sep)

# %%
print(len(su_events_df))
# Out:
# 19605

# %%
# Get summary on variable values
info_summary = {"variable": [], "# missing values": [], "# values == 0": [], "# values >= 1": []}

for su_key, su_value in SU_SCORES.items():
    info_summary["variable"].append(su_value)
    info_summary["# missing values"].append(su_events_df[su_key].isnull().sum())
    info_summary["# values == 0"].append(len(su_events_df.loc[su_events_df[su_key] == 0]))
    info_summary["# values >= 1"].append(len(su_events_df.loc[su_events_df[su_key] >= 1]))

info_summary = pd.DataFrame(info_summary)
info_summary
# Out:
#                                  variable  # missing values  # values == 0  \
# 0                             Ever tried?             10372           7032
# 1                       Total times 1 sip             10082           7328
# 2  Ever alcohol not in religious ceremony             17404            521
# 3                        Regular drinking             19590             14
# 4                            Total drinks             19590              1
# 5             Drinking days past 6 months             19604              0
#
#    # values >= 1
# 0           2201
# 1           2195
# 2           1680
# 3              1
# 4             14
# 5              1

# %%
# Filter out missing values from the sufficiently supported scores
SU_SCORES = {"tlfb_alc_sip": "Ever tried?",
             "su_isip_1_calc": "Total times 1 sip"}
su_events_df = su_events_df[(su_events_df["tlfb_alc_sip"].notnull()) & (su_events_df["su_isip_1_calc"].notnull())]
print("There are {} events after filtering out missing values".format(len(su_events_df)))
# Out:
# There are 9229 events after filtering out missing values

# %%
# Plot distribution of sips
import pygal
from pygal import Config
from abcd.plotting.pygal.rendering import display_html

capped_sips = [x if x < 50 else 50 for x in list(su_events_df["su_isip_1_calc"])]
su_events_df["su_isip_1_calc_capped"] = capped_sips
plot = pygal.Box()
plot.title = 'Total times subjects had one sip of an alcoholic drink, capped at 50'
plot.add("# times 1 sip", list(su_events_df["su_isip_1_calc_capped"]))
display_html(plot)
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#     <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#     </head>
#     <body>
#         <figure>
#         <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-6695a41c-ca91-440d-813b-0df89521b889" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (etree) ©Kozea 2012-2016 on 2023-07-05--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-6695a41c-ca91-440d-813b-0df89521b889{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-6695a41c-ca91-440d-813b-0df89521b889 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-6695a41c-ca91-440d-813b-0df89521b889 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6695a41c-ca91-440d-813b-0df89521b889 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-6695a41c-ca91-440d-813b-0df89521b889 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-6695a41c-ca91-440d-813b-0df89521b889 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-6695a41c-ca91-440d-813b-0df89521b889 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-6695a41c-ca91-440d-813b-0df89521b889{background-color:rgba(249,249,249,1)}#chart-6695a41c-ca91-440d-813b-0df89521b889 path,#chart-6695a41c-ca91-440d-813b-0df89521b889 line,#chart-6695a41c-ca91-440d-813b-0df89521b889 rect,#chart-6695a41c-ca91-440d-813b-0df89521b889 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-6695a41c-ca91-440d-813b-0df89521b889 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .graph{fill:rgba(0,0,0,.87)}#chart-6695a41c-ca91-440d-813b-0df89521b889 text.no_data{fill:rgba(0,0,0,1)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .title{fill:rgba(0,0,0,1)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis .line{stroke:rgba(0,0,0,1)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis text.major{fill:rgba(0,0,0,1)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis.y .guides:hover .guide.line,#chart-6695a41c-ca91-440d-813b-0df89521b889 .line-graph .axis.x .guides:hover .guide.line,#chart-6695a41c-ca91-440d-813b-0df89521b889 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-6695a41c-ca91-440d-813b-0df89521b889 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-6695a41c-ca91-440d-813b-0df89521b889 .ci{stroke:rgba(0,0,0,.87)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .reactive.active,#chart-6695a41c-ca91-440d-813b-0df89521b889 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-6695a41c-ca91-440d-813b-0df89521b889 .ci .reactive.active{stroke-width:1.5}#chart-6695a41c-ca91-440d-813b-0df89521b889 .series text{fill:rgba(0,0,0,1)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-6695a41c-ca91-440d-813b-0df89521b889 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-6695a41c-ca91-440d-813b-0df89521b889 .tooltip .value{font-size:1.5em}#chart-6695a41c-ca91-440d-813b-0df89521b889 .bound{font-size:.5em}#chart-6695a41c-ca91-440d-813b-0df89521b889 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-6695a41c-ca91-440d-813b-0df89521b889 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-6695a41c-ca91-440d-813b-0df89521b889 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-6695a41c-ca91-440d-813b-0df89521b889 .color-0,#chart-6695a41c-ca91-440d-813b-0df89521b889 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-6695a41c-ca91-440d-813b-0df89521b889 .text-overlay .color-0 text{fill:black}
# #chart-6695a41c-ca91-440d-813b-0df89521b889 text.no_data{text-anchor:middle}#chart-6695a41c-ca91-440d-813b-0df89521b889 .guide.line{fill:none}#chart-6695a41c-ca91-440d-813b-0df89521b889 .centered{text-anchor:middle}#chart-6695a41c-ca91-440d-813b-0df89521b889 .title{text-anchor:middle}#chart-6695a41c-ca91-440d-813b-0df89521b889 .legends .legend text{fill-opacity:1}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis.x text{text-anchor:middle}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis.y text{text-anchor:end}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis.y text[transform].backwards{text-anchor:start}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis.y2 text{text-anchor:start}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis.y2 text[transform].backwards{text-anchor:end}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-6695a41c-ca91-440d-813b-0df89521b889 .horizontal .axis.y .guide.line,#chart-6695a41c-ca91-440d-813b-0df89521b889 .horizontal .axis.y2 .guide.line,#chart-6695a41c-ca91-440d-813b-0df89521b889 .vertical .axis.x .guide.line{opacity:0}#chart-6695a41c-ca91-440d-813b-0df89521b889 .horizontal .axis.always_show .guide.line,#chart-6695a41c-ca91-440d-813b-0df89521b889 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis.y .guides:hover .guide.line,#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis.y2 .guides:hover .guide.line,#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis.x .guides:hover .guide.line{opacity:1}#chart-6695a41c-ca91-440d-813b-0df89521b889 .axis .guides:hover text{opacity:1}#chart-6695a41c-ca91-440d-813b-0df89521b889 .nofill{fill:none}#chart-6695a41c-ca91-440d-813b-0df89521b889 .subtle-fill{fill-opacity:.2}#chart-6695a41c-ca91-440d-813b-0df89521b889 .dot{stroke-width:1px;fill-opacity:1;stroke-opacity:1}#chart-6695a41c-ca91-440d-813b-0df89521b889 .dot.active{stroke-width:5px}#chart-6695a41c-ca91-440d-813b-0df89521b889 .dot.negative{fill:transparent}#chart-6695a41c-ca91-440d-813b-0df89521b889 text,#chart-6695a41c-ca91-440d-813b-0df89521b889 tspan{stroke:none !important}#chart-6695a41c-ca91-440d-813b-0df89521b889 .series

# %%
# Number of "0" va "1" subjects for each site
import numpy as np
from abcd.data.define_splits import SITES
from abcd.plotting.pygal.colors import CAT_COLORS

from abcd.data.define_splits import SITES, save_restore_sex_fmri_splits
k = 5
splits = save_restore_sex_fmri_splits(k)

custom_style = pygal.style.Style(
    colors=tuple([CAT_COLORS['split'][str(split_ix)] for split_ix in range(5)])
    #,background='transparent'
    )

bar_chart = pygal.Bar(x_label_rotation=45, style=custom_style)
bar_chart.title = '# visits reporting trying alcohol on each site'
bar_chart.x_labels = [x.replace("site", "site ") for x in SITES]
for split_ix in range(k):
    per_site_values = []
    for site_id in SITES:
        subjects_in_split = splits[site_id][str(split_ix)]
        nr_visits = len(
            su_events_df.loc[(su_events_df["src_subject_id"].isin(subjects_in_split)) & (su_events_df['tlfb_alc_sip'] == 1)]
        )
        per_site_values.append(nr_visits)
    bar_chart.add(str(split_ix), per_site_values)
display_html(bar_chart)

"""

per_site_0_values = [len(su_events_df.loc[(su_events_df["tlfb_alc_sip"] == 0) & (su_events_df["site_id_l"] == site_id)]) for site_id in SITES]
per_site_1_values = [len(su_events_df.loc[(su_events_df["tlfb_alc_sip"] == 1) & (su_events_df["site_id_l"] == site_id)]) for site_id in SITES]
bar_chart.add(str("Never had"), per_site_0_values)
bar_chart.add(str("Had"), per_site_1_values)
display_html(bar_chart)
"""
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#     <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#     </head>
#     <body>
#         <figure>
#         <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (etree) ©Kozea 2012-2016 on 2023-07-05--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b{background-color:rgba(249,249,249,1)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b path,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b line,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b rect,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .graph{fill:rgba(0,0,0,.87)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b text.no_data{fill:rgba(0,0,0,1)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .title{fill:rgba(0,0,0,1)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .legends .legend text{fill:rgba(0,0,0,.87)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis .line{stroke:rgba(0,0,0,1)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis text.major{fill:rgba(0,0,0,1)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis.y .guides:hover .guide.line,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .line-graph .axis.x .guides:hover .guide.line,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .stackedline-graph .axis.x .guides:hover .guide.line,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .ci{stroke:rgba(0,0,0,.87)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .reactive.active,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .ci .reactive.active{stroke-width:1.5}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .series text{fill:rgba(0,0,0,1)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .tooltip .label{fill:rgba(0,0,0,.87)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .tooltip .value{font-size:1.5em}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .bound{font-size:.5em}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .color-0,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .color-0 a:visited{stroke:#9AE2E0;fill:#9AE2E0}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .color-1,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .color-1 a:visited{stroke:#6AB8E8;fill:#6AB8E8}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .color-2,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .color-2 a:visited{stroke:#A99EEC;fill:#A99EEC}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .color-3,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .color-3 a:visited{stroke:#FE8AA8;fill:#FE8AA8}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .color-4,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b . ...
# #chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b text.no_data{text-anchor:middle}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .guide.line{fill:none}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .centered{text-anchor:middle}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .title{text-anchor:middle}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .legends .legend text{fill-opacity:1}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis.x text{text-anchor:middle}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis.x:not(.web) text[transform]{text-anchor:start}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis.y text{text-anchor:end}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis.y text[transform].backwards{text-anchor:start}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis.y2 text{text-anchor:start}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis.y2 text[transform].backwards{text-anchor:end}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .horizontal .axis.y .guide.line,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .horizontal .axis.y2 .guide.line,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .vertical .axis.x .guide.line{opacity:0}#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .horizontal .axis.always_show .guide.line,#chart-9ddd0885-e6a9-4ed7-90c1-e6529658787b .vertical .axis.always_show .gui
# '\n\nper_site_0_values = [len(su_events_df.loc[(su_events_df["tlfb_alc_sip"] == 0) & (su_events_df["site_id_l"] == site_id)]) for site_id in SITES]\nper_site_1_values = [len(su_events_df.loc[(su_events_df["tlfb_alc_sip"] == 1) & (su_events_df["site_id_l"] == site_id)]) for site_id in SITES]\nbar_chart.add(str("Never had"), per_site_0_values)\nbar_chart.add(str("Had"), per_site_1_values)\ndisplay_html(bar_chart)\n'
