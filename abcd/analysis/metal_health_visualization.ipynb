# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from abcd.local.paths import core_path, output_path
from abcd.data.read_data import get_subjects_events, add_event_vars

# %%
# Fetch subjects and events
subjects_df, events_df = get_subjects_events()

# %%
# Filter out events to only leave the baselines
subjects_df, events_df = get_subjects_events()
baseline_events_df = events_df[events_df["eventname"] == "baseline_year_1_arm_1"] 
print("There are {} baseline events for {} subjects!".format(len(baseline_events_df), len(subjects_df)))
# Out:
# There are 9530 baseline events for 9879 subjects!

# %%
# Add mental health outcomes
MH_SCORES = {"cbcl_scr_syn_anxdep_t": "Anxious/Dep.",
             "cbcl_scr_syn_withdep_t": "Depression",
             "cbcl_scr_syn_somatic_t": "Somatic",
             "cbcl_scr_syn_social_t": "Social",
             "cbcl_scr_syn_attention_t": "Attention",
             "cbcl_scr_syn_rulebreak_t": "Rule-breaking",
             "cbcl_scr_syn_aggressive_t": "Aggressive",
             "cbcl_scr_syn_internal_t": "Internalizing",
             "cbcl_scr_syn_external_t": "Externalizing"}    

mental_health_file = os.path.join(core_path, "mental-health", "mh_p_cbcl.csv")
mh_events_df = add_event_vars(baseline_events_df, mental_health_file, vars=list(MH_SCORES.keys()))
print("From those, there are {} events with mental health scores".format(len(mh_events_df)))
# Out:
# From those, there are 9528 events with mental health scores
# c:\users\camgonza\desktop\abcd5\abcd\utils\io.py:24: DtypeWarning: Columns (124,128,132,136,140,144,148,152,156,160,164,168,172,176,180,184,188,192,196,200) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path, sep=sep)

# %%
# Count missing values
"""
for column in mh_events_df.columns:
    nr_missing_values = mh_events_df[[column]].isna().sum().sum()
    if nr_missing_values > 0:
        print("Column {} has {} missing values".format(column, nr_missing_values))
"""
# Remove missing values
mh_events_df = mh_events_df.dropna()
print("After removing missing values, the df has {} events".format(len(mh_events_df)))
# Out:
# After removing missing values, the df has 9495 events

# %%
# Plot distribution of variables
import pygal
from pygal import Config
from abcd.plotting.pygal.rendering import display_html

plot = pygal.Box()
plot.title = 'Child behavior checklist CBCL syndrome scales'
for var_id, var_name in MH_SCORES.items():
    plot.add(var_name, list(mh_events_df[var_id]))
display_html(plot)
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#     <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#     </head>
#     <body>
#         <figure>
#         <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-3af2460a-c88e-4836-9fca-5889f59fa64c" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (etree) ©Kozea 2012-2016 on 2023-07-04--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-3af2460a-c88e-4836-9fca-5889f59fa64c{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-3af2460a-c88e-4836-9fca-5889f59fa64c{background-color:rgba(249,249,249,1)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c path,#chart-3af2460a-c88e-4836-9fca-5889f59fa64c line,#chart-3af2460a-c88e-4836-9fca-5889f59fa64c rect,#chart-3af2460a-c88e-4836-9fca-5889f59fa64c circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .graph{fill:rgba(0,0,0,.87)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c text.no_data{fill:rgba(0,0,0,1)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .title{fill:rgba(0,0,0,1)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .legends .legend text{fill:rgba(0,0,0,.87)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .axis .line{stroke:rgba(0,0,0,1)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .axis text.major{fill:rgba(0,0,0,1)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .axis.y .guides:hover .guide.line,#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .line-graph .axis.x .guides:hover .guide.line,#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .stackedline-graph .axis.x .guides:hover .guide.line,#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .ci{stroke:rgba(0,0,0,.87)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .reactive.active,#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .ci .reactive.active{stroke-width:1.5}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .series text{fill:rgba(0,0,0,1)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .tooltip .label{fill:rgba(0,0,0,.87)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .tooltip .label{fill:rgba(0,0,0,.87)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .tooltip .value{font-size:1.5em}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .bound{font-size:.5em}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .color-0,#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .color-1,#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .color-2,#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .color-2 a:visited{stroke:#009688;fill:#009688}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .color-3,#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .color-4,#chart-3af2460a-c88e-4836-9fca-5889f59fa64c . ...
# #chart-3af2460a-c88e-4836-9fca-5889f59fa64c text.no_data{text-anchor:middle}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .guide.line{fill:none}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .centered{text-anchor:middle}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .title{text-anchor:middle}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .legends .legend text{fill-opacity:1}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .axis.x text{text-anchor:middle}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .axis.x:not(.web) text[transform]{text-anchor:start}#chart-3af2460a-c88e-4836-9fca-5889f59fa64c .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-3af2460a-c88e-4836-9fc

# %%
# Normalize in the (0, 1) range
from abcd.data.var_tailoring.normalization import normalize_var

for var_id in MH_SCORES.keys():
    mh_events_df = normalize_var(mh_events_df, var_id, var_id+"_n")
    
plot = pygal.Box()
plot.title = 'Child behavior checklist CBCL syndrome scales (after normalization)'    
for var_id, var_name in MH_SCORES.items():
    plot.add(var_name, list(mh_events_df[var_id+"_n"]))
display_html(plot)
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#     <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#     </head>
#     <body>
#         <figure>
#         <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (etree) ©Kozea 2012-2016 on 2023-07-04--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1{background-color:rgba(249,249,249,1)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 path,#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 line,#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 rect,#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .graph{fill:rgba(0,0,0,.87)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 text.no_data{fill:rgba(0,0,0,1)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .title{fill:rgba(0,0,0,1)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .axis .line{stroke:rgba(0,0,0,1)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .axis text.major{fill:rgba(0,0,0,1)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .axis.y .guides:hover .guide.line,#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .line-graph .axis.x .guides:hover .guide.line,#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .ci{stroke:rgba(0,0,0,.87)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .reactive.active,#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .ci .reactive.active{stroke-width:1.5}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .series text{fill:rgba(0,0,0,1)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .tooltip .value{font-size:1.5em}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .bound{font-size:.5em}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .color-0,#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .color-1,#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .color-2,#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .color-3,#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .color-3 a:visited{stroke:#FFC107;fill:#FFC107}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .color-4,#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 . ...
# #chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 text.no_data{text-anchor:middle}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .guide.line{fill:none}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .centered{text-anchor:middle}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .title{text-anchor:middle}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .legends .legend text{fill-opacity:1}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .axis.x text{text-anchor:middle}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-d661dad7-e73c-4f2a-a58c-5df3b1be28d1 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-d661dad7-e73c-4f2a-a58

# %%
from abcd.data.define_splits import save_restore_sex_fmri_splits
from abcd.data.NETWORKS import CONNECTIONS
from sklearn.linear_model import LinearRegression, SGDRegressor
from abcd.analysis.methods.sklearn_fitting import calculate_regession_results, plot_results_one_site

site_splits = save_restore_sex_fmri_splits(k=5)
feature_columns = CONNECTIONS

# %%
# Linear Regression results
y_column = "cbcl_scr_syn_internal_t_n"
model = LinearRegression()
results = calculate_regession_results(model, mh_events_df, site_splits, feature_columns, y_column)
results
# Out:
# 100%|██████████| 21/21 [00:03<00:00,  5.63it/s]
#       split  MAE mean   MAE std  Max. error mean  Max. error std
# 0     Train  0.153322  0.000379         0.697271        0.008307
# 1   ID Test  0.154966  0.000912         0.667171        0.008141
# 2  OOD Test  0.154817  0.006641         0.589719        0.058785

# %%
plot_results_one_site(model, mh_events_df, site_splits, feature_columns, y_column, y_column_name=MH_SCORES["cbcl_scr_syn_internal_t"], site_id="site01")
# Out:
#     <!DOCTYPE html>
#     <html>
#     <head>
#     <script type="text/javascript" src="http://kozea.github.com/pygal.js/javascripts/svg.jquery.js"></script>
#     <script type="text/javascript" src="https://kozea.github.io/pygal.js/2.0.x/pygal-tooltips.min.js""></script>
#     </head>
#     <body>
#         <figure>
#         <?xml version='1.0' encoding='utf-8'?>
# <svg xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" id="chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6" class="pygal-chart" viewBox="0 0 800 600"><!--Generated with pygal 3.0.0 (etree) ©Kozea 2012-2016 on 2023-07-04--><!--http://pygal.org--><!--http://github.com/Kozea/pygal--><defs><style type="text/css">#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6{-webkit-user-select:none;-webkit-font-smoothing:antialiased;font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .title{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .legends .legend text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis text{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis text.major{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .text-overlay text.value{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:16px}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .text-overlay text.label{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:10px}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .tooltip{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:14px}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 text.no_data{font-family:Consolas,"Liberation Mono",Menlo,Courier,monospace;font-size:64px}
# #chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6{background-color:rgba(249,249,249,1)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 path,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 line,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 rect,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 circle{-webkit-transition:150ms;-moz-transition:150ms;transition:150ms}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .graph &gt; .background{fill:rgba(249,249,249,1)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .plot &gt; .background{fill:rgba(255,255,255,1)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .graph{fill:rgba(0,0,0,.87)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 text.no_data{fill:rgba(0,0,0,1)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .title{fill:rgba(0,0,0,1)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .legends .legend text{fill:rgba(0,0,0,.87)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .legends .legend:hover text{fill:rgba(0,0,0,1)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis .line{stroke:rgba(0,0,0,1)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis .guide.line{stroke:rgba(0,0,0,.54)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis .major.line{stroke:rgba(0,0,0,.87)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis text.major{fill:rgba(0,0,0,1)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis.y .guides:hover .guide.line,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .line-graph .axis.x .guides:hover .guide.line,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .stackedline-graph .axis.x .guides:hover .guide.line,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .xy-graph .axis.x .guides:hover .guide.line{stroke:rgba(0,0,0,1)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis .guides:hover text{fill:rgba(0,0,0,1)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .reactive{fill-opacity:.7;stroke-opacity:.8;stroke-width:1}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .ci{stroke:rgba(0,0,0,.87)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .reactive.active,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .active .reactive{fill-opacity:.8;stroke-opacity:.9;stroke-width:4}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .ci .reactive.active{stroke-width:1.5}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .series text{fill:rgba(0,0,0,1)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .tooltip rect{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,1);-webkit-transition:opacity 150ms;-moz-transition:opacity 150ms;transition:opacity 150ms}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .tooltip .label{fill:rgba(0,0,0,.87)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .tooltip .legend{font-size:.8em;fill:rgba(0,0,0,.54)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .tooltip .x_label{font-size:.6em;fill:rgba(0,0,0,1)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .tooltip .xlink{font-size:.5em;text-decoration:underline}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .tooltip .value{font-size:1.5em}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .bound{font-size:.5em}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .max-value{font-size:.75em;fill:rgba(0,0,0,.54)}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .map-element{fill:rgba(255,255,255,1);stroke:rgba(0,0,0,.54) !important}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .map-element .reactive{fill-opacity:inherit;stroke-opacity:inherit}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .color-0,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .color-0 a:visited{stroke:#F44336;fill:#F44336}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .color-1,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .color-1 a:visited{stroke:#3F51B5;fill:#3F51B5}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .color-2,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .color-2 a:visited{stroke:#009688;fill:#009688}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .text-overlay .color-0 text{fill:black}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .text-overlay .color-1 text{fill:black}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .text-overlay .color-2 text{fill ...
# #chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 text.no_data{text-anchor:middle}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .guide.line{fill:none}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .centered{text-anchor:middle}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .title{text-anchor:middle}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .legends .legend text{fill-opacity:1}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis.x text{text-anchor:middle}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis.x:not(.web) text[transform]{text-anchor:start}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis.x:not(.web) text[transform].backwards{text-anchor:end}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis.y text{text-anchor:end}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis.y text[transform].backwards{text-anchor:start}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis.y2 text{text-anchor:start}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis.y2 text[transform].backwards{text-anchor:end}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis .guide.line{stroke-dasharray:4,4;stroke:black}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis .major.guide.line{stroke-dasharray:6,6;stroke:black}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .horizontal .axis.y .guide.line,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .horizontal .axis.y2 .guide.line,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .vertical .axis.x .guide.line{opacity:0}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .horizontal .axis.always_show .guide.line,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .vertical .axis.always_show .guide.line{opacity:1 !important}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis.y .guides:hover .guide.line,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis.y2 .guides:hover .guide.line,#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis.x .guides:hover .guide.line{opacity:1}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .axis .guides:hover text{opacity:1}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4b8d6 .nofill{fill:none}#chart-b53e330b-aad1-4f8f-8f0c-9d3b98f4
